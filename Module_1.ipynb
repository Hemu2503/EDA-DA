# %% [markdown]
# <a href="https://colab.research.google.com/github/Hemu2503/EDA-DA/blob/main/Module_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [GITHUB LINK](https://github.com/Hemu2503/EDA-DA)
#
# https://github.com/Hemu2503/EDA-DA

# %% [markdown]
# ## Module 1: Introduction to Exploratory Data Analysis (EDA)

# %%
# Importing the necessary libraries
import pandas as pd

# Load the dataset from the new GitHub link
url = 'https://github.com/Hemanth-Vundavilli/EDA-DA/blob/main/Benefits.csv?raw=true'
data = pd.read_csv(url)

data.head()
# Out:
#    rownames  stateur  statemb  state  age  tenure     joblost nwhite school12  \
# 0         1      4.5      167     42   49      21       other     no       no
# 1         2     10.5      251     55   26       2  slack_work     no       no
# 2         3      7.2      260     21   40      19       other     no      yes
# 3         4      5.8      245     56   51      17  slack_work    yes       no
# 4         5      6.5      125     58   33       1  slack_work     no      yes
#
#       sex bluecol smsa married dkids dykids  yrdispl        rr head   ui
# 0    male     yes  yes      no    no     no        7  0.290631  yes  yes
# 1    male     yes  yes      no   yes    yes       10  0.520202  yes   no
# 2  female     yes  yes     yes    no     no       10  0.432490  yes  yes
# 3  female     yes  yes     yes    no     no       10  0.500000   no  yes
# 4    male     yes  yes     yes   yes    yes        4  0.390625  yes   no

# %% [markdown]
# ## Step 2: Explore the Dataset
# ### Dimensions of the Dataset

# %%
data.shape
# Out:
# (4877, 19)

# %% [markdown]
# ### Summary of the Dataset

# %%
data.describe(include='all')
# Out:
#            rownames      stateur      statemb        state          age  \
# count   4877.000000  4877.000000  4877.000000  4877.000000  4877.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean    2439.000000     7.511031   180.660242    52.808079    36.129998
# std     1408.012962     2.500579    43.241595    25.834967    10.600737
# min        1.000000     2.200000    84.000000    11.000000    20.000000
# 25%     1220.000000     5.700000   150.000000    31.000000    28.000000
# 50%     2439.000000     7.200000   177.000000    55.000000    34.000000
# 75%     3658.000000     9.000000   205.000000    74.000000    43.000000
# max     4877.000000    18.000000   293.000000    95.000000    61.000000
#
#              tenure     joblost nwhite school12   sex bluecol  smsa married  \
# ...

# %% [markdown]
# ### Missing Values Count

# %%
data.isnull().sum()
# Out:
# rownames    0
# stateur     0
# statemb     0
# state       0
# age         0
# tenure      0
# joblost     0
# nwhite      0
# school12    0
# sex         0
# bluecol     0
# smsa        0
# married     0
# dkids       0
# dykids      0
# yrdispl     0
# rr          0
# head        0
# ui          0
# dtype: int64

# %% [markdown]
# ### Numerical Summary

# %%
data.describe()
# Out:
#           rownames      stateur      statemb        state          age  \
# count  4877.000000  4877.000000  4877.000000  4877.000000  4877.000000
# mean   2439.000000     7.511031   180.660242    52.808079    36.129998
# std    1408.012962     2.500579    43.241595    25.834967    10.600737
# min       1.000000     2.200000    84.000000    11.000000    20.000000
# 25%    1220.000000     5.700000   150.000000    31.000000    28.000000
# 50%    2439.000000     7.200000   177.000000    55.000000    34.000000
# 75%    3658.000000     9.000000   205.000000    74.000000    43.000000
# max    4877.000000    18.000000   293.000000    95.000000    61.000000
#
#             tenure      yrdispl           rr
# count  4877.000000  4877.000000  4877.000000
# mean      5.664138     5.203609     0.438366
# std       6.279938     3.095116     0.106194
# min       1.000000     1.000000     0.038610
# 25%       2.000000     2.000000     0.375212
# 50%       3.000000     5.000000     0.490446
# ...

# %% [markdown]
# ## Conclusion
# This notebook serves as a foundational overview of the dataset, encompassing loading and initial exploration. We'll delve deeper into the data through more extensive exploratory data analysis (EDA) in the upcoming modules.
